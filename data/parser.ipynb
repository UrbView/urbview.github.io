# %%
import pandas as pd

csv = pd.read_csv('hamburg.csv', delimiter=';')
csv = csv.drop('Unnamed: 0', axis = 1)

# %%
subsample = csv.sample(100)
subsample
# Out:
#        Type                  DHID                           Name   Latitude  \
# 411712    Q     de:06432:8477:1:1                  NEppertshause   49,92923
# 657101    S          de:05962:258      Lüd., Abzw. Brüninghausen  51,233508
# 685493    S        de:03153:40229     Seesen, Emil-Mechau-Straße  51,879601
# 698239    Q  de:03241:7058:1:7059                        Bokeloh  52,400525
# 176297    Q    de:09376:80378:0:2                              2  49,477488
# ...     ...                   ...                            ...        ...
# 146676    A      de:09275:4100:83                           Taxi  48,405907
# 38999     Q    de:08215:1403:2:11                            SEV  48,917208
# 340495    S        de:03360:42510  Himbergen(Göhrde) Grundschule  53,093535
# 25596     Q    de:08126:10935:0:2     Ri. Südosten (Mangoldsall)  49,235109
# 251271    S    de:11000:900082204           Berlin, Hörsingsteig  52,423964
#
#         Longitude
# 411712   8,862436
# ...

# %%
subsample.to_csv('reduced_hamburg.csv', index_label='index', sep = ';')
